# %%
# import module
import pandas as pd

# assign data
df = pd.DataFrame({'Name': [' RACHEL  ', ' MONICA  ', ' PHOEBE  ',
                                   '  ROSS    ', 'CHANDLER', ' JOEY    '],
                          
                          'Age': [30, 35, 37, 33, 34, 30],
                          
                          'Salary': [100000, 93000, 88000, 120000, 94000, 95000],
                          
                          'JOB': ['DESIGNER', 'CHEF', 'MASUS', 'PALENTOLOGY',
                                  'IT', 'ARTIST']})

# display dataframe
display(df)
# Out:
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST

# %%
df.loc[
(df['Salary'] >= 100000) &
(df['Age']< 40) &
(df['JOB'].str.startswith('D')),
['Name', 'JOB']
]
# Out:
#         Name       JOB
# 0   RACHEL    DESIGNER

# %% [raw]
# Excellent question — and this is where a lot of learners get confused.
#
# Let’s **break down exactly when and why** we use **square brackets `[ ]`**, **round brackets `( )`**, and even **curly brackets `{ }`** in Python — especially in **Pandas**.
#
# ---
#
# ## 🎯 Focus: Why and When We Use Brackets in This Code
#
# ### The code:
#
# ```python
# dataFrame.loc[
#     (dataFrame['Salary'] >= 100000) &
#     (dataFrame['Age'] < 40) &
#     (dataFrame['JOB'].str.startswith('D')),
#     ['Name', 'JOB']
# ]
# ```
#
# Let’s understand each bracket type.
#
# ---
#
# ### ✅ 1. **Round brackets `( )`**
#
# → These are used for **grouping conditions** (just like in math).
#
# **Why?**
# To make sure Python does operations in the correct order.
# Example:
#
# ```python
# (dataFrame['Salary'] >= 100000) & (dataFrame['Age'] < 40)
# ```
#
# Without the round brackets `()`, Python gets confused and throws an error.
#
# ---
#
# ### ✅ 2. **Square brackets `[ ]`**
#
# → These are used to **select elements** from a list, DataFrame, or Series.
#
# You’ll see them used:
#
# * To filter rows (`df[condition]`)
# * To select columns (`df[['Name', 'Age']]`)
# * With `.loc[]` and `.iloc[]`
#
# In your code:
#
# ```python
# dataFrame.loc[ <condition> , ['Name', 'JOB'] ]
# ```
#
# You're saying:
#
# * First part inside `.loc[ ___ , ___ ]` is the condition → gives you the **rows** you want.
# * Second part is `['Name', 'JOB']` → tells Pandas which **columns** to keep.
#
# ---
#
# ### ✅ 3. **Curly brackets `{ }`**
#
# → These are for **dictionaries** only. You use them when defining data like this:
#
# ```python
# {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}
# ```
#
# So you **don’t** use them in filtering.
#
# ---
#
# ## 🧠 Tip to Remember:
#
# * Use `()` around **each condition**.
# * Use `[]` to **select rows/columns** or when inside `.loc[]`, `.iloc[]`, or general slicing.
# * Never mix them up — Python expects each type for specific things.
#
# ---
#
# Want to do a **mini-practice** right now?
# I can give you an example to identify where to place which bracket. Ready?
