# %%
import pandas as pd

df = pd.read_csv("nba.csv", index_col="Name")
df.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
# !ls
# Out:
# Day02_NBA_Indexing.ipynb nba.csv

# %%
# !ls Day02-indexing&Selecting
# Out:
# zsh:1: command not found: Selecting

# %%
df["Age"].head() #single column selection
# Out:
# Name
# Avery Bradley    25.0
# Jae Crowder      25.0
# John Holland     27.0
# R.J. Hunter      22.0
# Jonas Jerebko    29.0
# Name: Age, dtype: float64

# %%
df[['Age', 'College', 'Salary']].head() #Multiple column selection.
# Out:
#                 Age            College     Salary
# Name
# Avery Bradley  25.0              Texas  7730337.0
# Jae Crowder    25.0          Marquette  6796117.0
# John Holland   27.0  Boston University        NaN
# R.J. Hunter    22.0      Georgia State  1148640.0
# Jonas Jerebko  29.0                NaN  5000000.0

# %%
df.loc['Avery Bradley'] # Select single row by label
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object

# %%
df.loc[["Avery Bradley", "R.J. Hunter"]] # Select Multiple Rows by Label (.loc)
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#                      College     Salary
# Name
# Avery Bradley          Texas  7730337.0
# R.J. Hunter    Georgia State  1148640.0

# %%
# Select Specific Rows and Columns
df.loc[['Avery Bradley','R.J. Hunter'],['Team', 'Position', 'Salary']]
# Out:
#                          Team Position     Salary
# Name
# Avery Bradley  Boston Celtics       PG  7730337.0
# R.J. Hunter    Boston Celtics       SG  1148640.0

# %%
#  All Rows + Specific Columns

df.loc[:,['Team', 'Position','Salary']].head()
# Out:
#                          Team Position     Salary
# Name
# Avery Bradley  Boston Celtics       PG  7730337.0
# Jae Crowder    Boston Celtics       SF  6796117.0
# John Holland   Boston Celtics       SG        NaN
# R.J. Hunter    Boston Celtics       SG  1148640.0
# Jonas Jerebko  Boston Celtics       PF  5000000.0

# %%
df.iloc[3]
# Out:
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %%
df.iloc[[3, 5, 7]]
# Out:
#                         Team  Number Position   Age Height  Weight  \
# Name
# R.J. Hunter   Boston Celtics    28.0       SG  22.0    6-5   185.0
# Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#                     College      Salary
# Name
# R.J. Hunter   Georgia State   1148640.0
# Amir Johnson            NaN  12000000.0
# Kelly Olynyk        Gonzaga   2165160.0

# %%
df.iloc[[3, 4], [1, 2]]
# Out:
#                Number Position
# Name
# R.J. Hunter      28.0       SG
# Jonas Jerebko     8.0       PF

# %%
df.iloc[:, [1, 2]].head()
# Out:
#                Number Position
# Name
# Avery Bradley     0.0       PG
# Jae Crowder      99.0       SF
# John Holland     30.0       SG
# R.J. Hunter      28.0       SG
# Jonas Jerebko     8.0       PF

# %%
df.at["Avery Bradley", "Age"]
# Out:
# 25.0

# %%
df.query("Age > 25 and College == 'Duke'") #Query the DataFrame
# Out:
#                                     Team  Number Position   Age Height  \
# Name
# Lance Thomas             New York Knicks    42.0       SF  28.0    6-8
# Elton Brand           Philadelphia 76ers    42.0       PF  37.0    6-9
# JJ Redick           Los Angeles Clippers     4.0       SG  31.0    6-4
# Mike Dunleavy              Chicago Bulls    34.0       SG  35.0    6-9
# Dahntay Jones        Cleveland Cavaliers    30.0       SG  35.0    6-6
# Miles Plumlee            Milwaukee Bucks    18.0        C  27.0   6-11
# Luol Deng                     Miami Heat     9.0       SF  31.0    6-9
# Josh McRoberts                Miami Heat     4.0       PF  29.0   6-10
# Kyle Singler       Oklahoma City Thunder     5.0       SF  28.0    6-8
# Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0    6-5
# Mason Plumlee     Portland Trail Blazers    24.0        C  26.0   6-11
#
#                   Weight College      Salary
# Name
# Lance Thomas       235.0    Duke   1636842.0
# ...

# %%
# Show all players earning more than $10 million
df[df['Salary']>10_000_000]
# Out:
#                                     Team  Number Position   Age Height  \
# Name
# Amir Johnson              Boston Celtics    90.0       PF  29.0    6-9
# Brook Lopez                Brooklyn Nets    11.0        C  28.0    7-0
# Thaddeus Young             Brooklyn Nets    30.0       PF  27.0    6-8
# Carmelo Anthony          New York Knicks     7.0       SF  32.0    6-8
# Robin Lopez              New York Knicks     8.0        C  28.0    7-0
# ...                                  ...     ...      ...   ...    ...
# Serge Ibaka        Oklahoma City Thunder     9.0       PF  26.0   6-10
# Enes Kanter        Oklahoma City Thunder    11.0        C  24.0   6-11
# Russell Westbrook  Oklahoma City Thunder     0.0       PG  27.0    6-3
# Derrick Favors                 Utah Jazz    15.0       PF  24.0   6-10
# Gordon Hayward                 Utah Jazz    20.0       SF  26.0    6-8
#
#                    Weight       College      Salary
# Name
# ...

# %%
df[(df['Age']< 25) & (df['College'].isnull())]
# Out:
#                                    Team  Number Position   Age Height  Weight  \
# Name
# Sergey Karasev            Brooklyn Nets    10.0       SG  22.0    6-7   208.0
# Thanasis Antetokounmpo  New York Knicks    43.0       SF  23.0    6-7   205.0
# Kristaps Porzingis      New York Knicks     6.0       PF  20.0    7-3   240.0
# Bismack Biyombo         Toronto Raptors     8.0        C  23.0    6-9   245.0
# Bruno Caboclo           Toronto Raptors    20.0       SF  20.0    6-9   205.0
# Lucas Nogueira          Toronto Raptors    92.0        C  23.0    7-0   220.0
# Jonas Valanciunas       Toronto Raptors    17.0        C  24.0    7-0   255.0
# Cristiano Felicio         Chicago Bulls     6.0       PF  23.0   6-10   275.0
# Giannis Antetokounmpo   Milwaukee Bucks    34.0       SF  21.0   6-11   222.0
# Damien Inglis           Milwaukee Bucks    17.0       SF  21.0    6-8   246.0
# Clint Capela            Houston Rockets    15.0       PF  22.0   6-10   240.0
# ...

# %%
df.query("College =='Duke' and Salary > 5000000")
# Out:
#                                     Team  Number Position   Age Height  \
# Name
# JJ Redick           Los Angeles Clippers     4.0       SG  31.0    6-4
# Kyrie Irving         Cleveland Cavaliers     2.0       PG  24.0    6-3
# Jabari Parker            Milwaukee Bucks    12.0       PF  21.0    6-8
# Luol Deng                     Miami Heat     9.0       SF  31.0    6-9
# Josh McRoberts                Miami Heat     4.0       PF  29.0   6-10
# Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0    6-5
#
#                   Weight College      Salary
# Name
# JJ Redick          190.0    Duke   7085000.0
# Kyrie Irving       193.0    Duke  16407501.0
# Jabari Parker      250.0    Duke   5152440.0
# Luol Deng          220.0    Duke  10151612.0
# Josh McRoberts     240.0    Duke   5543725.0
# Gerald Henderson   215.0    Duke   6000000.0

# %%
df.iloc[0:5, [0, 1]]  # adjust column positions if needed
# Out:
#                          Team  Number
# Name
# Avery Bradley  Boston Celtics     0.0
# Jae Crowder    Boston Celtics    99.0
# John Holland   Boston Celtics    30.0
# R.J. Hunter    Boston Celtics    28.0
# Jonas Jerebko  Boston Celtics     8.0

# %%
df.at["Avery Bradley", "Position"]
# Out:
# 'PG'

# %%
df['Team'].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz',
#        nan], dtype=object)

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
df.sort_values(by="Salary", ascending=False).head(5)
# Out:
#                                 Team  Number Position   Age Height  Weight  \
# Name
# Kobe Bryant       Los Angeles Lakers    24.0       SF  37.0    6-6   212.0
# LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8   250.0
# Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8   240.0
# Dwight Howard        Houston Rockets    12.0        C  30.0   6-11   265.0
# Chris Bosh                Miami Heat     1.0       PF  32.0   6-11   235.0
#
#                       College      Salary
# Name
# Kobe Bryant               NaN  25000000.0
# LeBron James              NaN  22970500.0
# Carmelo Anthony      Syracuse  22875000.0
# Dwight Howard             NaN  22359364.0
# Chris Bosh       Georgia Tech  22192730.0

# %%
# Players who have no college listed
df[df["College"].isnull()].head()
# Out:
#                                    Team  Number Position   Age Height  Weight  \
# Name
# Jonas Jerebko            Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson             Boston Celtics    90.0       PF  29.0    6-9   240.0
# Bojan Bogdanovic          Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# Sergey Karasev            Brooklyn Nets    10.0       SG  22.0    6-7   208.0
# Thanasis Antetokounmpo  New York Knicks    43.0       SF  23.0    6-7   205.0
#
#                        College      Salary
# Name
# Jonas Jerebko              NaN   5000000.0
# Amir Johnson               NaN  12000000.0
# Bojan Bogdanovic           NaN   3425510.0
# Sergey Karasev             NaN   1599840.0
# Thanasis Antetokounmpo     NaN     30888.0

# %%
df_filled = df.fillna({"Salary": 0})
df_filled.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        0.0
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0
